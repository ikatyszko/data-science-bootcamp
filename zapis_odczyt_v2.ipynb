# %% [markdown]
# <a href="https://colab.research.google.com/github/ikatyszko/data-science-bootcamp/blob/main/zapis_odczyt_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df_raw = pd.read_csv('appstore_games.csv')

# %%
df = df_raw.copy()
df = df.drop(columns= ['URL', 'Icon URL', 'Subtitle', 'Description', 'In-app Purchases'])

# %%
df.set_index('ID', inplace = True)

# %%
df.sort_index()
# Out:
#                                  Name  Average User Rating  User Rating Count  \
# ID
# 284921427                      Sudoku                  4.0             3553.0
# 284926400                     Reversi                  3.5              284.0
# 284946595                     Morocco                  3.0             8376.0
# 285755462               Sudoku (Free)                  3.5           190394.0
# 285831220                Senet Deluxe                  3.5               28.0
# ...                               ...                  ...                ...
# 1474626442  Stack Puzzle : Rise Tower                  NaN                NaN
# 1474919257                  EachOther                  NaN                NaN
# 1474962324         Rabbit Vs Tortoise                  NaN                NaN
# 1474963671                     FaTaLL                  NaN                NaN
# 1475076711   The Three Kingdoms :Bomb                  NaN                NaN
#
# ...

# %%
df.describe()
# Out:
#        Average User Rating  User Rating Count         Price          Size
# count          7561.000000       7.561000e+03  16983.000000  1.700600e+04
# mean              4.060905       3.306531e+03      0.813419  1.157064e+08
# std               0.751428       4.232256e+04      7.835732  2.036477e+08
# min               1.000000       5.000000e+00      0.000000  5.132800e+04
# 25%               3.500000       1.200000e+01      0.000000  2.295014e+07
# 50%               4.500000       4.600000e+01      0.000000  5.676895e+07
# 75%               4.500000       3.090000e+02      0.000000  1.330271e+08
# max               5.000000       3.032734e+06    179.990000  4.005591e+09

# %%
 df.describe(include=['object']).T
# Out:
#                               count unique  \
# Name                          17007  16847
# Developer                     17007   8693
# Age Rating                    17007      4
# Languages                     16947    990
# Primary Genre                 17007     21
# Genres                        17007   1004
# Original Release Date         17007   3084
# Current Version Release Date  17007   2512
#
#                                                                      top  \
# Name                                                           Additions
# Developer                     Tapps Tecnologia da Informa\xe7\xe3o Ltda.
# Age Rating                                                            4+
# Languages                                                             EN
# Primary Genre                                                      Games
# Genres                                           Games, Strategy, Puzzle
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.columns = [col.replace(' ', '_') for col in df.columns]

# %%
df.head()
# Out:
#                     name  average_user_rating  user_rating_count  price  \
# ID
# 284921427         Sudoku                  4.0             3553.0   2.99
# 284926400        Reversi                  3.5              284.0   1.99
# 284946595        Morocco                  3.0             8376.0   0.00
# 285755462  Sudoku (Free)                  3.5           190394.0   0.00
# 285831220   Senet Deluxe                  3.5               28.0   2.99
#
#                           developer age_rating  \
# ID
# 284921427  Mighty Mighty Good Games         4+
# 284926400          Kiss The Machine         4+
# 284946595               Bayou Games         4+
# 285755462  Mighty Mighty Good Games         4+
# 285831220           RoGame Software         4+
#
#                                                    languages        size  \
# ID
# 284921427  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 284926400                                                 EN  12328960.0
# ...

# %%
df.primary_genre.value_counts().nlargest(5)
# Out:
# Games            16286
# Education          222
# Entertainment      198
# Utilities           77
# Sports              60
# Name: primary_genre, dtype: int64

# %%
  df.primary_genre.value_counts().nlargest(5).index
# Out:
# Index(['Games', 'Education', 'Entertainment', 'Utilities', 'Sports'], dtype='object')

# %%
list(  df.primary_genre.value_counts().nlargest(5).index)
# Out:
# ['Games', 'Education', 'Entertainment', 'Utilities', 'Sports']

# %%
df.age_rating.value_counts()
# Out:
# 4+     11806
# 9+      2481
# 12+     2055
# 17+      665
# Name: age_rating, dtype: int64

# %%
df.age_rating.value_counts().plot(kind='pie')

# %%
df.age_rating.value_counts().hist()

# %%
type(df.age_rating.value_counts())
# Out:
# pandas.core.series.Series

# %%
import seaborn as sbs

# %%
sbs.set()

# %%
df.price
# Out:
# ID
# 284921427     2.99
# 284926400     1.99
# 284946595     0.00
# 285755462     0.00
# 285831220     2.99
#               ...
# 1474626442    0.00
# 1474919257    0.00
# 1474962324    0.00
# 1474963671    0.00
# 1475076711    0.00
# Name: price, Length: 17007, dtype: float64

# %%
df.price.value_counts()
# Out:
# 0.00      14212
# 0.99       1078
# 1.99        515
# 2.99        471
# 4.99        237
# 3.99        163
# 9.99         88
# 11.99        59
# 5.99         42
# 6.99         32
# 179.99       30
# 7.99         17
# 8.99         13
# 19.99         9
# 14.99         4
# 12.99         3
# 16.99         2
# 29.99         2
# 139.99        1
# 99.99         1
# 37.99         1
# 36.99         1
# 18.99         1
# 59.99         1
# Name: price, dtype: int64

# %%
df.average_user_rating.value_counts()
# Out:
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: average_user_rating, dtype: int64

# %%
df.languages
# Out:
# ID
# 284921427     DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# 284926400                                                    EN
# 284946595                                                    EN
# 285755462     DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...
# 285831220     DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...
#                                     ...
# 1474626442                                                   EN
# 1474919257                                                   EN
# 1474962324                                                   EN
# 1474963671                                                   EN
# 1475076711                                               EN, ZH
# Name: languages, Length: 17007, dtype: object

# %%
df.languages.value_counts()
# Out:
# EN                                                                            12467
# EN, ZH                                                                          354
# CS, NL, EN, FR, DE, IT, JA, KO, PL, PT, RU, ZH, ES, SV, ZH, TR                  277
# EN, ZH, ZH                                                                      248
# EN, DE                                                                          147
#                                                                               ...
# DA, NL, EN, FI, FR, DE, IT, JA, KO, NO, PL, PT, RU, ZH, ES, SV, ZH, TR, UK        1
# EN, FR, IT, JA, KO, PT, RU, ES, TR                                                1
# DA, NL, EN, FR, DE, IT, NB, PL, PT, ZH, ES, SV, ZH, TR                            1
# EN, PT, ZH                                                                        1
# AR, NL, EN, FR, DE, ID, IT, JA, KO, PT, RU, ZH, ES, SV, TH, ZH, TR, VI            1
# Name: languages, Length: 990, dtype: int64

# %%
tab = df.languages.str.split(', ')

# %%
nam_lang = df.languages.str.split(', ').str.len()

# %%
df.languages.str.split(', ').str.len().sort_values(ascending=False)
# Out:
# ID
# 1256307763    111.0
# 1362979803     76.0
# 329218549      66.0
# 578072806      65.0
# 578075914      65.0
#               ...
# 1449929230      NaN
# 1450659337      NaN
# 1452403154      NaN
# 1452491712      NaN
# 1459639864      NaN
# Name: languages, Length: 17007, dtype: float64

# %%
df['num_lang'] = nam_lang

# %%
df.head(2)
# Out:
#               name  average_user_rating  user_rating_count  price  \
# ID
# 284921427   Sudoku                  4.0             3553.0   2.99
# 284926400  Reversi                  3.5              284.0   1.99
#
#                           developer age_rating  \
# ID
# 284921427  Mighty Mighty Good Games         4+
# 284926400          Kiss The Machine         4+
#
#                                                    languages        size  \
# ID
# 284921427  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 284926400                                                 EN  12328960.0
#
#           primary_genre                   genres original_release_date  \
# ID
# 284921427         Games  Games, Strategy, Puzzle            11/07/2008
# 284926400         Games   Games, Strategy, Board            11/07/2008
#
#           current_version_release_date  num_lang
# ID
# 284921427                   30/05/2017      17.0
# 284926400                   17/05/2018       1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17007 entries, 284921427 to 1475076711
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          17007 non-null  object
#  1   average_user_rating           7561 non-null   float64
#  2   user_rating_count             7561 non-null   float64
#  3   price                         16983 non-null  float64
#  4   developer                     17007 non-null  object
#  5   age_rating                    17007 non-null  object
#  6   languages                     16947 non-null  object
#  7   size                          17006 non-null  float64
#  8   primary_genre                 17007 non-null  object
#  9   genres                        17007 non-null  object
#  10  original_release_date         17007 non-null  object
#  11  current_version_release_date  17007 non-null  object
# ...

# %%
df.average_user_rating.value_counts(dropna=False)
# Out:
# NaN    9446
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: average_user_rating, dtype: int64

# %%
df.isnull().sum()
# Out:
# name                               0
# average_user_rating             9446
# user_rating_count               9446
# price                             24
# developer                          0
# age_rating                         0
# languages                         60
# size                               1
# primary_genre                      0
# genres                             0
# original_release_date              0
# current_version_release_date       0
# num_lang                          60
# dtype: int64

# %%
df.dropna()
# Out:
#                              name  average_user_rating  user_rating_count  \
# ID
# 284921427                  Sudoku                  4.0             3553.0
# 284926400                 Reversi                  3.5              284.0
# 284946595                 Morocco                  3.0             8376.0
# 285755462           Sudoku (Free)                  3.5           190394.0
# 285831220            Senet Deluxe                  3.5               28.0
# ...                           ...                  ...                ...
# 1473084135               Die Last                  3.0                6.0
# 1473181500            Basic Slosh                  5.0               30.0
# 1473559573     Idle Racing Tycoon                  5.0               51.0
# 1473680543     Glow Hockey Strike                  5.0                5.0
# 1474461379  Agadmator Chess Clock                  5.0               33.0
#
#             price                 developer age_rating  \
# ID
# ...

# %%
df.isnull().sum()
# Out:
# name                               0
# average_user_rating             9446
# user_rating_count               9446
# price                             24
# developer                          0
# age_rating                         0
# languages                         60
# size                               1
# primary_genre                      0
# genres                             0
# original_release_date              0
# current_version_release_date       0
# num_lang                          60
# dtype: int64
